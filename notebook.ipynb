# %%
import streamlit as st
import plotly.graph_objects as go
from utils import load_data
df = load_data()
df.head()
# Out:
# 2026-04-09 20:32:09.178 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2026-04-09 20:32:09.181 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2026-04-09 20:32:09.182 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
#          brand          model       engine  battery_capacity  horse_power  \
# 0      ferrari  sf90 stradale           v8            3990.0          963
# 1  rolls royce        phantom          v12            6749.0          563
# 2         ford            ka+  1.2l petrol            1200.0           70
# 3     mercedes        gt 63 s           v8            3982.0          630
# 4         audi     audi r8 gt          v10            5204.0          602
#
#    top_speed  performance      price       fuel_type  seats  torque
# 0        340          2.5  1100000.0  hybrid in plug      2   800.0
# 1        250          5.3   460000.0          petrol      5   900.0
# 2        165         10.5    12000.0          petrol      5   100.0
# 3        250          3.2   161000.0          petrol      4   900.0
# 4        320          3.6   253290.0          petrol      2   560.0

# %%
auto_seleccionado1 = "sf90 stradale"
filtrar_auto_seleccionado1 = df[df["model"] == auto_seleccionado1]
filtrar_auto_seleccionado1
# Out:
#      brand          model engine  battery_capacity  horse_power  top_speed  \
# 0  ferrari  sf90 stradale     v8            3990.0          963        340
#
#    performance      price       fuel_type  seats  torque
# 0          2.5  1100000.0  hybrid in plug      2   800.0

# %%
filtrar_auto_seleccionado1["engine"][0]
# Out:
# 'v8'

# %%
for col in df.select_dtypes(include="object").columns:
    print(col)
    print(df[col].nunique())
# Out:
# brand
# 31
# model
# 1189
# engine
# 347
# fuel_type
# 14
